# %%
# The main purpose for this project is to change categorical data into binary/boolean form
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score,KFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
dumb1 = pd.read_csv('C:\\Users\\solomon kure\\Desktop\\1.03. Dummies.csv')
dummy_dumb1 = pd.get_dummies(dumb1['Attendance'],drop_first = True)
dummy_dumb1 = pd.concat([dumb1,dummy_dumb1], axis = 1)
dummy_dumb1.drop(columns = ['Attendance'],axis = 1,inplace = True)
print(dummy_dumb1.head())
# Out:
#     SAT   GPA    Yes
# 0  1714  2.40  False
# 1  1664  2.52  False
# 2  1760  2.54  False
# 3  1685  2.74  False
# 4  1693  2.83  False
